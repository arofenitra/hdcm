# %% [markdown]
# <a href="https://colab.research.google.com/github/arofenitra/hdcm/blob/master/TDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ripser
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.3/827.3 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.1 MB/s eta 0:00:00
# ...
#   Created wheel for hopcroftkarp: filename=hopcroftkarp-1.2.5-py2.py3-none-any.whl size=18104 sha256=71b4620f2f2b965ffde47b414095332d107a1929f073b92ee011c45c17643d8a
#   Stored in directory: /root/.cache/pip/wheels/2a/fd/fe/f4b8fd82894e1d9e04040ef41dc5ae6eb7a8e9b0ef5a9402fe
# Successfully built hopcroftkarp
# ...

# %%
import numpy as np
from ripser import Rips
rips = Rips()
data = np.linspace(0,100,200).reshape(100,2)
print((data.shape))
# print(data)
diagrams = rips.fit_transform(data)
rips.plot(diagrams)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)
# (100, 2)

# %%
for i in range(len(diagrams)):
    print(diagrams[i].shape)
# Out:
# (100, 2)
# (21, 2)
