# %% [markdown]
# # Implementation of topology of attention maps

# %% [markdown]
# ## 1. LLM Generation Parameters
# - **Temperature ($\tau$=0.8)**
# $$p'(x) = softmax(logits(x)/τ) = softmax(\log(x/(1-x))/τ)$$
# - **Top-p nucleus sampling, p=0.95** : To eliminate low probability "tail" token, we want To Find minimal set V such that
# $$ Σ_{i∈V} p_i ≥ 0.95$$
# ## 2. Attention Matrix Reconstruction: Building the Token Graph
# - **Attention tensor structure** :
# Initial forward pass : ```(num_layers, num_heads, prompt_len, prompt_len)```.
# Generation steps : ```(num_layers, num_heads, 1, current_seq_len)``` per step.
# - **Formulation**
# $$A[i,j] = \frac{1}{LH} Σ_{l=1}^L Σ_{h=1}^H \text{attention}_l^h[i,j]$$
# where: $L = 32$ (layers), $H = 32$ (heads), $A[i,j] =$ average attention weight from token $i$ to token $j$
# ## 3. Distance matrix construction
# $$d(i,j) = \delta_{ij}(1-\max(A[i,j],A[j,i]))$$
# ## 4. Toplogical features
# - $H_0$ features (connected components) : Bar $[b,d]$ which component born at $b$ and die aat $d$. Normalization ensures comparability accross different sequence length.
# - $H_1$ features (loops and cycles) : Total persistent is $\sum_{\text{bars}} (d-b)$. Normalization ensures comparability.
# ## 5. Feature engineering
# - ```mtd_h0_norm```: Normalized maximum H₀ persistence. It measures the fragmentation in generated tokens.
# - ```mtd_h1_norm```: Normalized maximum H₁ persistence. It measures the cyclic reasoning patterns.
# - Self attention diagonals. High values mean model is ignoring context
# $$\text{prompt self attn} = (1/|P|) Σ_{i∈P} A[i,i] $$
# $$\text{gen self attn} = (1/|G|) Σ_{i∈G} A[i,i]$$
# - Mean log probability : Measures generation confidence
# $$\text{mean log prob} = (1/|G|) Σ_{i∈G} \log p(\text{token i})$$
# ## 6. Hallucination Detection Framework: The Mathematical Model
# Problem Formalization
#
# Let $X ∈ ℝ^d$ be the feature vector ($d$ = number of features)
# Let $y ∈ {0,1}$ where $y=1$ indicates hallucination
# Goal: Learn $f: ℝ^d → [0,1]$ where $f(X) ≈ P(y=1|X)$
#
#
# - LightGBM Classifier
#
# The model uses gradient boosting with the objective:
# $$f = \arg \min_{f} Σ_{i=1 to n} L(y_i, f(X_i)) + Ω(f)$$
# where:
#
#     $L$ = binary cross-entropy loss: $-y·log(p) - (1-y)·log(1-p)$
# $Ω(f)$ = regularization term preventing overfitting

# %%
# !pip install --upgrade pip setuptools wheel 
# !pip install -U bitsandbytes

# %%
# !cmake --version

# %%
# !pip install cmake 
# !pip install human_eval ripser
# !pip install lightgbm
# !pip install accelerate

# %%
#!/usr/bin/env python
# coding: utf-8
import os
import sys
import json
import numpy as np
import torch
# import xgboost as xgb
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    set_seed
)
from human_eval.data import read_problems, write_jsonl
from human_eval.execution import check_correctness
from ripser import ripser

import lightgbm as lgb

# %%
# Configuration - Easy to modify for other models/benchmarks
MODEL_NAME = "codellama/CodeLlama-7b-hf"  # Can switch to other models
BENCHMARK = "human_eval"  # Options: "human_eval" or "mbpp"
TEMPERATURE = 0.8
TOP_P = 0.95
MAX_NEW_TOKENS = 256
NUM_SHOTS = 0  # Zero-shot setting (HumanEval standard)
NUM_SAMPLES = 5  # Generations per problem for classifier training
SEEDS = [0, 1, 2, 3, 4]  # Seeds for reproducibility

# Critical: Set up sandbox for code execution
os.environ["HF_HOME"] = "/tmp"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

def setup_environment():
    """Initialize model, tokenizer, and benchmark problems"""
    print(f"Loading model: {MODEL_NAME}")
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    tokenizer.pad_token = tokenizer.eos_token
    
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        device_map="cuda:0",
        torch_dtype=torch.float16,

        # load_in_8bit=True,  # Add 8-bit quantization
        output_attentions=True,
        return_dict_in_generate=True
    ).eval()
    
    print(f"Loading benchmark: {BENCHMARK}")
    if BENCHMARK == "human_eval":
        problems = read_problems()
    elif BENCHMARK == "mbpp":
        # MBPP loading would go here (simplified for this example)
        raise NotImplementedError("MBPP support requires additional setup")
    else:
        raise ValueError(f"Unsupported benchmark: {BENCHMARK}")
    
    return model, tokenizer, problems
def generate_with_attention(model, tokenizer, prompt, seed):
    """Generate code completion with full attention matrix reconstruction"""
    set_seed(seed)
    
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    prompt_len = inputs["input_ids"].shape[1]
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=True,
            temperature=TEMPERATURE,
            top_p=TOP_P,
            num_return_sequences=1,
            output_attentions=True,
            output_scores=True,
            return_dict_in_generate=True
        )
    
    full_seq = outputs.sequences[0]
    generated_ids = full_seq[prompt_len:]
    generated_text = tokenizer.decode(generated_ids, skip_special_tokens=True)
    total_len = len(full_seq)
    
    # Initialize full attention matrix (averaged over layers AND heads)
    full_attention = torch.zeros((total_len, total_len), device=model.device, dtype=torch.float32)
    
    # Step 1: Process initial prompt attentions (step 0)
    initial_attentions = outputs.attentions[0]  # tuple of (layer0, ..., layer31)
    
    # Stack all layers, then average over layers AND heads
    # Each layer: [1, 32, P, P] → after squeeze: [32, P, P]
    stacked_initial = torch.stack([
        layer.squeeze(0) for layer in initial_attentions  # remove batch dim
    ], dim=0)  # → [num_layers, 32, P, P]
    
    # Average over layers (dim=0) AND heads (dim=1) → [P, P]
    avg_initial = stacked_initial.mean(dim=(0, 1))  # Key fix!
    full_attention[:prompt_len, :prompt_len] = avg_initial
    
    # Step 2: Process generation steps (step 1 onward)
    for step, step_attentions in enumerate(outputs.attentions[1:], start=prompt_len):
        # step_attentions: tuple of (layer0, ..., layer31), each [1, 32, 1, step+1]
        stacked_step = torch.stack([
            layer.squeeze(0) for layer in step_attentions  # → [32, 1, step+1]
        ], dim=0)  # → [num_layers, 32, 1, step+1]
        
    # traininingted (G) tokens
    prompt_mask = np.zeros(n, dtype=bool)
    prompt_mask[:prompt_len] = True
    gen_mask = ~prompt_mask
    
    return dist, prompt_mask, gen_mask

def compute_topological_features(dist, prompt_mask, gen_mask):
    """Compute MTD-inspired topological features"""
    n_prompt = prompt_mask.sum()
    n_gen = gen_mask.sum()
    
    # Compute persistent homology explicitly as distance matrix
    dgms = ripser(dist, distance_matrix=True, maxdim=1)['dgms']
    
    # Extract H0 and H1 features
    h0_bars = dgms[0][:-1]  # Exclude infinite bar
    h1_bars = dgms[1]
    
    # Compute MTD approximation features
    features = {
        'h0_max_persistence': np.max(h0_bars[:, 1] - h0_bars[:, 0]) if len(h0_bars) > 0 else 0,
        'h1_total_persistence': np.sum(h1_bars[:, 1] - h1_bars[:, 0]) if len(h1_bars) > 0 else 0,
        'num_h1_bars': len(h1_bars),
        'prompt_size': n_prompt,
        'gen_size': n_gen
    }
    
    # Normalize by component sizes (as specified in requirements)
    if n_gen > 0:
        features['h0_max_persistence_norm'] = features['h0_max_persistence'] / n_gen
    else:
        features['h0_max_persistence_norm'] = 0
        
    if n_prompt > 0:
        features['h1_total_persistence_norm'] = features['h1_total_persistence'] / n_prompt
    else:
        features['h1_total_persistence_norm'] = 0
    
    return features

def extract_attention_features(attention, prompt_len):
    """Extract all required features from attention matrix"""
    dist, prompt_mask, gen_mask = build_distance_matrix(attention, prompt_len)
    topo_features = compute_topological_features(dist, prompt_mask, gen_mask)
    
    # Extract attention statistics
    prompt_attn = attention[:prompt_len, :prompt_len]
    gen_attn = attention[prompt_len:, prompt_len:]
    
    features = {
        # Topological features (normalized)
        'mtd_h0_norm': topo_features['h0_max_persistence_norm'],
        'mtd_h1_norm': topo_features['h1_total_persistence_norm'],
        
        # Attention statistics
        'prompt_self_attn': torch.diagonal(prompt_attn).mean().item() if prompt_len > 0 else 0,
        'gen_self_attn': torch.diagonal(gen_attn).mean().item() if gen_attn.shape[0] > 0 else 0,
        
        # Basic features
        'prompt_len': prompt_len,
        'gen_len': attention.shape[0] - prompt_len,
        'h1_num_bars': topo_features['num_h1_bars']
    }
    
    return features
def detect_hallucination(generated_code, problem):
    """Execute code to determine hallucination (failure to pass tests)"""
    try:
        # Use the correct signature for HumanEval
        result = check_correctness(
            problem=problem,          # Pass the entire problem dict
            completion=generated_code,
            timeout=3.0,
            completion_id="temp"
        )
        return not result["passed"]  # Hallucination = failed tests
    except Exception as e:
        print(f"Error in execution for problem: {e}")
        return True  # Treat execution errors as hallucinations

def collect_training_data(model, tokenizer, problems):
    """Generate dataset with features and hallucination labels"""
    training_data = []
    
    for task_id, problem in tqdm(problems.items(), desc="Collecting data"):
        prompt = problem["prompt"]
        
        for seed in SEEDS[:NUM_SAMPLES]:
            # Generate code with attention
            gen_result = generate_with_attention(model, tokenizer, prompt, seed)
            
            # Extract features
            attn_features = extract_attention_features(
                gen_result["attention_matrix"],
                gen_result["prompt_len"]
            )
            
            # Add probability features
            # Add probability features with safe log calculation
            safe_probs = [max(p, 1e-10) for p in gen_result["token_probs"]]
            mean_log_prob = np.mean(np.log(safe_probs))
            attn_features.update({
                'mean_log_prob': mean_log_prob,
                'task_id': task_id,
                'seed': seed
            })
            
            # Determine hallucination label
            is_hallucinated = detect_hallucination(
                gen_result["generated_text"],
                problem
            )
            
            training_data.append({
                "features": attn_features,
                "label": int(is_hallucinated),  # 1 = hallucinated, 0 = correct
                "code": gen_result["generated_text"]
            })
    
    return training_data
import pandas as pd 
def train_classifier(data):
    """Train XGBoost classifier on collected features"""
    # Prepare data
    X = []
    y = []
    feature_names = None
    
    for item in data :
        if feature_names is None:
            feature_names = sorted([k for k in item["features"].keys() 
                                  if k not in ["task_id", "seed"]])
        
        X.append([item["features"][k] for k in feature_names])
        y.append(item["label"])
    
    X = np.array(X)
    y = np.array(y)
    
    # Split data (simple holdout)
    split_idx = int(0.8 * len(X))
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]
    
    # # Train classifier
    # clf = xgb.XGBClassifier(
    #     objective='binary:logistic',
    #     eval_metric='logloss',
    #     random_state=42,
    #     use_label_encoder=False
    # )
    # clf.fit(X_train, y_train)
    clf = lgb.LGBMClassifier(
        objective='binary',
        random_state=42,
        verbose=-1  # Silences LightGBM output, remove if you want to see training logs
    )
    clf.fit(X_train, y_train)
    # Evaluate
    train_acc = clf.score(X_train, y_train)
    test_acc = clf.score(X_test, y_test)
    
    print(f"Classifier trained. Train accuracy: {train_acc:.4f}, Test accuracy: {test_acc:.4f}")
    return clf, feature_names

def evaluate_pass_at_k(model, tokenizer, problems, classifier, feature_names):
    """Evaluate pass@1 with hallucination filtering"""
    results = []
    total_correct = 0
    # At the start of evaluate_pass_at_k
    sample_problem = next(iter(problems.values()))
    required_keys = ["task_id", "prompt", "test"]
    missing_keys = [k for k in required_keys if k not in sample_problem]
    if missing_keys:
        raise ValueError(f"Problem dictionary missing required keys: {missing_keys}")
    for task_id, problem in tqdm(problems.items(), desc="Evaluating pass@1"):
        prompt = problem["prompt"]
        best_code = None
        best_score = -np.inf
        
        # Generate multiple candidates
        for seed in SEEDS:
            gen_result = generate_with_attention(model, tokenizer, prompt, seed)
            attn_features = extract_attention_features(
                gen_result["attention_matrix"],
                gen_result["prompt_len"]
            )
            
            # Add probability features
            probs_array = np.array(gen_result["token_probs"])
            mean_log_prob = np.mean(np.log(probs_array + 1e-10))  # Add epsilon AFTER converting to array
            attn_features['mean_log_prob'] = mean_log_prob
            
            # Prepare features for classifier
            # When preparing features for classifier
            feature_values = []
            for k in feature_names:
                if k in attn_features:
                    feature_values.append(attn_features[k])
                else:
                    # Use default value for missing features
                    feature_values.append(0.0 if "norm" in k or "prob" in k else 1.0)
            X = pd.DataFrame([feature_values], columns=feature_names)
            halluc_prob = classifier.predict_proba(X)[0][1]
            
            # Score = confidence in non-hallucination + log probability
            score = (1 - halluc_prob) + mean_log_prob
            
            if score > best_score:
                best_score = score
                best_code = gen_result["generated_text"]
        
        # Execute best candidate
        result = check_correctness(
            problem=problem,
            completion=best_code,
            timeout=3.0,
            completion_id=task_id
        )
        
        is_correct = result["passed"]
        total_correct += int(is_correct)
        
        results.append({
            "task_id": task_id,
            "completion": best_code,
            "passed": is_correct,
            "hallucination_prob": 1 - (best_score - mean_log_prob)  # Approximation
        })
    
    pass_at_1 = total_correct / len(problems)
    print(f"Final pass@1 after hallucination filtering: {pass_at_1:.4f}")
    return results, pass_at_1

# %%
# def main():
    # Setup
model, tokenizer, problems = setup_environment()


# if __name__ == "__main__":
#     main()
# Out:
# Loading model: codellama/CodeLlama-7b-hf
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading benchmark: human_eval

# %%
# # Step 1: Collect training data with hallucination labels
# print("\n=== Collecting training data ===")
# training_data = collect_training_data(model, tokenizer, problems)

# # Save raw data for analysis
# with open("training_data.json", "w") as f:
#     json.dump([{**item, "features": {k: float(v) if isinstance(v, np.float32) else v 
#                                     for k,v in item["features"].items()}} 
#                 for item in training_data], f)
# Out:
# === Collecting training data ===
# Collecting data:   0%|                                  | 0/164 [00:00<?, ?it/s]/beegfs/home/arofenitra.rarivonjy/ai/lib/python3.12/site-packages/transformers/generation/utils.py:1733: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed in v5. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   1%|▏                       | 1/164 [00:48<2:11:13, 48.30s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   1%|▎                       | 2/164 [01:37<2:12:25, 49.05s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   2%|▍                       | 3/164 [02:37<2:24:23, 53.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   2%|▌                       | 4/164 [03:12<2:03:34, 46.34s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   3%|▋                       | 5/164 [04:14<2:17:57, 52.06s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   4%|▉                       | 6/164 [05:11<2:21:25, 53.71s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   4%|█                       | 7/164 [05:54<2:11:24, 50.22s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   5%|█▏                      | 8/164 [06:55<2:19:22, 53.60s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   5%|█▎                      | 9/164 [07:22<1:57:31, 45.49s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   6%|█▍                     | 10/164 [08:24<2:09:39, 50.51s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   7%|█▌                     | 11/164 [09:17<2:10:54, 51.34s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   7%|█▋                     | 12/164 [10:17<2:16:50, 54.01s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   8%|█▊                     | 13/164 [11:09<2:14:14, 53.34s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   9%|█▉                     | 14/164 [11:50<2:04:09, 49.66s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:   9%|██                     | 15/164 [12:50<2:10:32, 52.57s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  10%|██▏                    | 16/164 [13:40<2:08:10, 51.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  10%|██▍                    | 17/164 [14:26<2:02:46, 50.11s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  11%|██▌                    | 18/164 [15:24<2:07:24, 52.36s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  12%|██▋                    | 19/164 [16:25<2:12:49, 54.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  12%|██▊                    | 20/164 [17:27<2:16:55, 57.05s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  13%|██▉                    | 21/164 [18:17<2:11:05, 55.01s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  13%|███                    | 22/164 [19:20<2:15:43, 57.35s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  14%|███▏                   | 23/164 [20:11<2:10:09, 55.39s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  15%|███▎                   | 24/164 [21:00<2:04:58, 53.56s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  15%|███▌                   | 25/164 [21:57<2:06:24, 54.56s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  16%|███▋                   | 26/164 [22:55<2:07:53, 55.61s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  16%|███▊                   | 27/164 [23:46<2:04:03, 54.33s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  17%|███▉                   | 28/164 [24:33<1:58:23, 52.23s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  18%|████                   | 29/164 [25:13<1:49:14, 48.55s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  18%|████▏                  | 30/164 [26:04<1:49:55, 49.22s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  19%|████▎                  | 31/164 [27:07<1:58:01, 53.25s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  20%|████▍                  | 32/164 [28:09<2:02:45, 55.80s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  20%|████▋                  | 33/164 [29:21<2:12:47, 60.82s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  21%|████▊                  | 34/164 [30:26<2:14:12, 61.95s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  21%|████▉                  | 35/164 [31:26<2:12:26, 61.60s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  22%|█████                  | 36/164 [32:28<2:11:11, 61.50s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  23%|█████▏                 | 37/164 [32:58<1:50:23, 52.16s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  23%|█████▎                 | 38/164 [34:01<1:56:22, 55.42s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  24%|█████▍                 | 39/164 [35:02<1:58:53, 57.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  24%|█████▌                 | 40/164 [35:52<1:53:16, 54.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:
/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  90%|███████████████████▋  | 147/164 [2:23:22<17:01, 60.09s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  90%|███████████████████▊  | 148/164 [2:24:23<16:02, 60.15s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  91%|███████████████████▉  | 149/164 [2:25:30<15:35, 62.37s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  91%|████████████████████  | 150/164 [2:26:37<14:53, 63.82s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  92%|████████████████████▎ | 151/164 [2:27:21<12:29, 57.67s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  93%|████████████████████▍ | 152/164 [2:28:25<11:56, 59.69s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  93%|████████████████████▌ | 153/164 [2:29:35<11:30, 62.77s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  94%|████████████████████▋ | 154/164 [2:30:44<10:46, 64.70s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  95%|████████████████████▊ | 155/164 [2:31:42<09:22, 62.54s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  95%|████████████████████▉ | 156/164 [2:32:37<08:03, 60.42s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  96%|█████████████████████ | 157/164 [2:33:40<07:08, 61.21s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  96%|█████████████████████▏| 158/164 [2:34:43<06:10, 61.70s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  97%|█████████████████████▎| 159/164 [2:35:46<05:10, 62.17s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  98%|█████████████████████▍| 160/164 [2:36:55<04:16, 64.18s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  98%|█████████████████████▌| 161/164 [2:38:05<03:17, 65.93s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  99%|█████████████████████▋| 162/164 [2:38:42<01:54, 57.23s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data:  99%|█████████████████████▊| 163/164 [2:39:44<00:58, 58.53s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Collecting data: 100%|██████████████████████| 164/164 [2:40:46<00:00, 58.82s/it]

# %%
with open("training_data.json","r") as f:
    training_data = json.load(f)
print(f"Loaded {len(training_data)} training samples")
# Step 2: Train hallucination classifier
print("\n=== Training hallucination classifier ===")
classifier, feature_names = train_classifier(training_data)
import joblib
joblib.dump({
    "classifier": classifier,
    "feature_names": feature_names
}, "hallucination_detector.joblib")
# Out:
# Loaded 820 training samples
#
# === Training hallucination classifier ===
# Classifier trained. Train accuracy: 1.0000, Test accuracy: 0.9817
# /beegfs/home/arofenitra.rarivonjy/ai/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /beegfs/home/arofenitra.rarivonjy/ai/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ['hallucination_detector.joblib']

# %%
# Step 3: Evaluate pass@1 with hallucination filtering
print("\n=== Evaluating final performance ===")
results, pass_at_1 = evaluate_pass_at_k(
    model, 
    tokenizer, 
    problems, 
    classifier, 
    feature_names
)

# Save results
write_jsonl("samples.jsonl", results)
print(f"Results saved to samples.jsonl. Final pass@1: {pass_at_1:.4f}")
# Out:
# === Evaluating final performance ===
# Evaluating pass@1:   0%|                                | 0/164 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   1%|▏                     | 1/164 [00:45<2:03:32, 45.47s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   1%|▎                     | 2/164 [01:34<2:08:18, 47.52s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   2%|▍                     | 3/164 [02:35<2:23:32, 53.49s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   2%|▌                     | 4/164 [03:10<2:03:12, 46.21s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   3%|▋                     | 5/164 [04:12<2:17:45, 51.98s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   4%|▊                     | 6/164 [05:08<2:20:46, 53.46s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   4%|▉                     | 7/164 [05:51<2:11:01, 50.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   5%|█                     | 8/164 [06:52<2:19:12, 53.54s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   5%|█▏                    | 9/164 [07:20<1:57:10, 45.36s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   6%|█▎                   | 10/164 [08:21<2:08:58, 50.25s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   7%|█▍                   | 11/164 [09:14<2:10:46, 51.28s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   7%|█▌                   | 12/164 [10:15<2:17:05, 54.12s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1:   8%|█▋                   | 13/164 [11:07<2:14:43, 53.53s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating pass@1